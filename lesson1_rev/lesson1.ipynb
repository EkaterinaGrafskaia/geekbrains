# %%
#Постройте на одном графике две кривые y(x) для функции двух переменной y(k,x)=cos(k∙x), 
#взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.
import matplotlib.pyplot as plt
import numpy as np

lag = 0.1
x = np.arange(0.0, 2*np.pi+lag, lag)
y = np.cos(x)

fig = plt.figure()
plt.plot(x, y)
plt.title('График функции y(k,x)=cos(k∙x), где k = 1')
plt.grid(True)
plt.show()

k = int(input("Введите значение k:"))
y1 = np.cos(k*x)

fig = plt.figure()
plt.plot(x, y1)
plt.title(f"'График функции y(k,x)=cos(k∙x), где k = {k}'")
plt.grid(True)
plt.show()
# Out:
# Введите значение k:4
